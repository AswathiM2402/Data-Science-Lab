# %% [markdown]
# **Experiment 13:
# Program to implement a simple web crawler and scrapping web pages.
# Algorithm
# A simple web crawler is a program that systematically navigates through web pages, extracts information, and may follow links to discover more pages.
# 1.	Seed URL: Start with an initial URL (seed URL) that you want to crawl.
# 2.	Initialize Queue: Create a queue to manage the URLs to be crawled. Initially, enqueue the seed URL.
# 3.	Crawl Loop:
# 4.	Start a loop that continues until the queue is empty or a specified limit is reached.
# 5.	Dequeue a URL from the queue.
# 6.	Send an HTTP request to fetch the HTML content of the page corresponding to the dequeued URL.
# 7.	Parse the HTML content to extract relevant information or links. Libraries like BeautifulSoup or Scrapy in Python are commonly used for HTML parsing.
# 8.	Process the extracted information or store it for further analysis.
# 9.	Enqueue any new URLs found on the page, ensuring they haven't been visited before to avoid duplicate crawling.
# 10.	Repeat: Repeat the crawl loop until the queue is empty or a specified limit is reached.
# 11.	Data Storage (Optional): Optionally, store the extracted data in a database or file for later analysis.
# 12.	Respect Robots.txt: Follow ethical practices by respecting the rules specified in the "robots.txt" file on websites, which can define which parts of a site are off-limits for crawling.
# 13.	Error Handling: Implement error handling to manage issues like connection errors or unexpected content during the crawling process
#
# **

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

def get_links(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    links = set()
    for anchor in soup.find_all('a'):
        href = anchor.get('href')
        if href and href.startswith('http'):
            links.add(href)
        else:
            full_url = urljoin(url, href)
            links.add(full_url)

    return links

def crawl(start_url, max_depth=3):
    visited = set()
    queue = [(start_url, 0)]

    while queue:
        current_url, depth = queue.pop(0)
        if current_url in visited or depth > max_depth:
            continue

        print(f"Depth: {depth}, Crawling: {current_url}")

        try:
            links = get_links(current_url)
            visited.add(current_url)
            queue.extend((link, depth + 1) for link in links if link not in visited)
        except Exception as e:
            print(f"Error crawling {current_url}: {e}")

if __name__ == "__main__":
    seed_url = "https://www.internshala.com"
    crawl(seed_url)
# Out:
# Depth: 0, Crawling: https://www.internshala.com
# Depth: 1, Crawling: https://trainings.internshala.com/machine-learning-course/?utm_source=is_web_internshala-menu-dropdown-most-popular
# Depth: 1, Crawling: https://trainings.internshala.com/android-course/?utm_source=is_web_internshala-menu-dropdown-most-popular
# Depth: 1, Crawling: https://www.internshala.com/internships/marketing-internship
# Depth: 1, Crawling: https://trainings.internshala.com/french-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/ansys-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/internships/hr-internship
# Depth: 1, Crawling: https://trainings.internshala.com/?utm_source=is_web_homepage_banner/#placement-and-job-guarantee-courses
# Depth: 1, Crawling: https://internshala.com/internships/civil-internship
# Depth: 1, Crawling: https://trainings.internshala.com/iot-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/internships/summer-research-fellowship-internship
# Depth: 1, Crawling: https://trainings.internshala.com/?utm_source=is_web_internshala-menu-dropdown1
# Depth: 1, Crawling: https://trainings.internshala.com/hacking-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/login/get_google
# Depth: 1, Crawling: https://internshala.com/internships/mba-internship
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-kolkata?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/stock-market-trading-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/product-management-placement-guarantee-course/?utm_source=is_web_IS-home-midsection_web5
# Depth: 1, Crawling: https://internshala.com/jobs/marketing-jobs?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/aws-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/human-resource-management-specialization?utm_source=is_web_internship-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/registration/student
# Depth: 1, Crawling: https://trainings.internshala.com/?utm_source=is_web_internshala_ham
# Depth: 1, Crawling: https://trainings.internshala.com/data-science-specialization/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/python-course/?utm_source=is_web_internshala-menu-dropdown-most-popular
# Depth: 1, Crawling: https://www.internshala.com/contact
# Depth: 1, Crawling: https://trainings.internshala.com/matlab-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/sql-data-analytics-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/electric-vehicles-placement-guarantee-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-chennai?utm_source=is_footer
# Depth: 1, Crawling: https://internshala.com/jobs-by-category/?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/full-stack-web-development-placement-guarantee-course/?utm_source=is_web_IS-home-midsection_web1
# Depth: 1, Crawling: https://trainings.internshala.com/plc-programming-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/internships/law-internship
# Depth: 1, Crawling: https://trainings.internshala.com/fusion-360-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/three-d-printing-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/internships/humanities-internship
# Depth: 1, Crawling: https://internshala.com/internships/content-writing-internship
# Depth: 1, Crawling: https://trainings.internshala.com/labview-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/human-resource-management-specialization/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/digital-marketing-jobs?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/react-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/finance-jobs?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/data-science-beginner-course/?utm_source=is_web_IS-home-midsection_web7
# Depth: 1, Crawling: https://internshala.com/internships/work-from-home-internships
# Depth: 1, Crawling: https://www.internshala.com/about_us
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-bangalore?utm_source=is_footer
# Depth: 1, Crawling: https://www.internshala.com/jobs
# Depth: 1, Crawling: https://www.internshala.com/hire-talent
# Depth: 1, Crawling: https://internshala.com/internships/digital-marketing-internship
# Depth: 1, Crawling: https://internshala.com/jobs/data-science-jobs?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://internshala.com/internships/internship-in-kolkata
# Depth: 1, Crawling: https://internshala.com/jobs/content-writing-jobs?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://www.internshala.com/internship/detail/market-research-work-from-home-job-internship-at-subhansh-sewa-trust1701422977?referral=homepage
# Depth: 1, Crawling: https://trainings.internshala.com/autocad-course/?utm_source=is_web_IS-home-midsection_web6
# Depth: 1, Crawling: https://trainings.internshala.com/digital-marketing-placement-guarantee-course/?utm_source=is_web_IS-home-midsection_web4
# Depth: 1, Crawling: https://internshala.com/internships/graphic-design-internship
# Depth: 1, Crawling: https://trainings.internshala.com/revit-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/digital-marketing-specialization?utm_source=is_web_job-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/wordpress-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/web-development-course/?utm_source=is_web_internshala-menu-dropdown-most-popular
# Depth: 1, Crawling: https://trainings.internshala.com/digital-marketing-course/?utm_source=is_web_IS-home-midsection_web3
# Depth: 1, Crawling: https://www.internshala.com/registration/student?utm_source=is_prefooter_homepage
# Depth: 1, Crawling: https://internshala.com/jobs-by-designation/?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://www.instagram.com/internshala/?utm_source=IS_footer
# Depth: 1, Crawling: https://trainings.internshala.com/sales-and-business-development-specialization?utm_source=is_web_internship-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/staad-pro-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/internships/civil-internship
# Depth: 1, Crawling: https://trainings.internshala.com/power-bi-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs-by-category/?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://www.internshala.com/job/detail/virtual-english-teacher-fresher-jobs-in-bangalore-at-planetspark1701340505?referral=homepage
# Depth: 1, Crawling: https://trainings.internshala.com/data-structures-algorithms-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/electric-vehicles-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/internships/internship-in-mumbai
# Depth: 1, Crawling: https://www.internshala.com/internships/electronics-internship
# Depth: 1, Crawling: https://trainings.internshala.com/excel-course/?utm_source=is_web_IS-home-midsection_web5
# Depth: 1, Crawling: https://internshala.com/internships/campus-ambassador-internship?utm_source=header
# Depth: 1, Crawling: https://www.internshala.com/internships-by-location/?utm_source=is_footer
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-jaipur?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/git-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/android-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/photography-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/data-science-jobs?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/business-analytics-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs-by-skill/?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-mumbai?utm_source=is_footer
# Depth: 1, Crawling: https://internshala.com/internships/marketing-internship
# Depth: 1, Crawling: https://trainings.internshala.com/statistics-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/electric-vehicles-placement-guarantee-course/?utm_source=is_web_IS-home-midsection_web8
# Depth: 1, Crawling: https://trainings.internshala.com/python-course/?utm_source=is_web_is-footer
# Depth: 1, Crawling: https://www.internshala.com/hire-talent?utm_source=ISfooterHome
# Depth: 1, Crawling: https://trainings.internshala.com/tableau-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/finance-jobs?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/excel-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/?utm_source=is_web_hp_banner_BOGO_Dec23&payment_source=hp_banner_BOGO_Dec23
# Depth: 1, Crawling: https://trainings.internshala.com/personal-finance-101-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/
menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/data-science-placement-guarantee-course/?utm_source=is_web_IS-home-midsection_web2
# Depth: 1, Crawling: https://trainings.internshala.com/web-development-course/?utm_source=is_web_is-footer
# Depth: 1, Crawling: https://trainings.internshala.com/interview-preparation-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-chennai?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/arduino-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/creo-parametric-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/python-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/deep-learning-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/business-communication-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/job/detail/english-faculty-fresher-jobs-in-jammu-at-planetspark1701340335?referral=homepage
# Depth: 1, Crawling: https://www.internshala.com/internships/internship-in-chennai
# Depth: 1, Crawling: https://www.internshala.com/internships/computer-science-internship
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-jaipur?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/excel-course/?utm_source=is_web_is-footer
# Depth: 1, Crawling: https://trainings.internshala.com/ar-vr-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/ppt-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://www.internshala.com/internships
# Depth: 1, Crawling: https://trainings.internshala.com/?utm_source=is_web_bottom_navigation
# Depth: 1, Crawling: https://www.internshala.com/job/detail/online-english-tutor-fresher-jobs-in-delhi-at-planetspark1701329090?referral=homepage
# Depth: 1, Crawling: https://internshala.com/jobs/graphic-design-jobs?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/digital-marketing-course/?utm_source=is_web_is-footer
# Depth: 1, Crawling: mailto:complaints@internshala.com
# Error crawling mailto:complaints@internshala.com: No connection adapters were found for 'mailto:complaints@internshala.com'
# Depth: 1, Crawling: https://trainings.internshala.com/python-course/?utm_source=is_web_IS-home-midsection_web2
# Depth: 1, Crawling: https://internshala.com/jobs/web-development-jobs?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/digital-marketing-specialization/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/internships/international-internship/?utm_source=banner&utm_medium=homepage
# Depth: 1, Crawling: https://www.internshala.com/internship/detail/operations-work-from-home-job-internship-at-leap-scholar1701509275?referral=homepage
# Depth: 1, Crawling: https://internshala.com/internships/internship-in-mumbai
# Depth: 1, Crawling: https://trainings.internshala.com/electric-vehicles-placement-guarantee-course?utm_source=is_web_job-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/acting-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/product-management-specialization?utm_source=is_web_internship-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/adobe-illustrator-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://internshala.com/internships/ppo-true
# Depth: 1, Crawling: https://trainings.internshala.com/pcb-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://trainings.internshala.com/vlsi-design-course/?utm_source=is_web_internshala-menu-dropdown
# Depth: 1, Crawling: https://blog.internshala.com/?utm_source=IS_footer
# Depth: 1, Crawling: https://internshala.com/internships/finance-internship
# Depth: 1, Crawling: https://internshala.com/jobs/computer-science-jobs?utm_source=is_menu_dropdown
# Depth: 1, Crawling: https://internshala.com/jobs/jobs-in-hyderabad?utm_source=is_footer
# Depth: 1, Crawling: https://trainings.internshala.com/autocad-three-d-course/?utm_source=is_web_internshala-menu-dropdown
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-84d2d1eaccbc> in <cell line: 38>()
#      38 if __name__ == "__main__":
#      39     seed_url = "https://www.internshala.com"
# ---> 40     crawl(seed_url)
#
# <ipython-input-8-84d2d1eaccbc> in crawl(start_url, max_depth)
#      30
#      31         try:
# ---> 32             links = get_links(current_url)
#      33             visited.add(current_url)
#      34             queue.extend((link, depth + 1) for link in links if link not in visited)
#
# <ipython-input-8-84d2d1eaccbc> in get_links(url)
#       4
#       5 def get_links(url):
# ----> 6     response = requests.get(url)
#       7     soup = BeautifulSoup(response.text, 'html.parser')
#       8
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
