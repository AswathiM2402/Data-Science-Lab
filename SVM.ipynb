# %%
#import the necessary libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
#load a dataset(Iris dataset is used in this example)
iris=datasets.load_iris()
x=iris.data[:,:2]#Take the first two feature for
y=iris.target

#split the data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#create an SVM calssifier (we can choose different kernel)
svm_classifier=SVC(kernel='linear',C=1,gamma=0.5)

#train the SVM classifier on the training data
svm_classifier.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=0.5, kernel='linear')

# %%
 #Make predictions on the test data
y_pred=svm_classifier.predict(x_test)
print(y_pred)

#calcluate accuracy
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# [1 0 2 1 2 0 1 2 1 1 2 0 0 0 0 2 2 1 1 2 0 1 0 2 2 2 2 2 0 0 0 0 2 0 0 1 2
#  0 0 0 1 2 2 0 0]
# 0.8
#
# Accuracy:80.00%

# %%
#gamma=0.7
vm_clf=SVC(kernel='rbf',C=1,gamma=0.7)
svm_classifier.fit(x_train,y_train)
y_pred=svm_classifier.predict(x_test)

#calcluate accuracy
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# 0.8
#
# Accuracy:80.00%

# %%
#gamma=100
#create an SVM calssifier (we can choose different kernel)
svm_classifier=SVC(kernel='rbf',C=1,gamma=100)

#train the SVM classifier on the training data
svm_classifier.fit(x_train,y_train)
#Make predictions on the test data
y_pred=svm_classifier.predict(x_test)

#calcluate accuracy
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# 0.5777777777777777
#
# Accuracy:57.78%

# %%
#gamma=500
#create an SVM calssifier (we can choose different kernel)
svm_classifier=SVC(kernel='rbf',C=1,gamma=500)

#train the SVM classifier on the training data
svm_classifier.fit(x_train,y_train)
#Make predictions on the test data
y_pred=svm_classifier.predict(x_test)

#calcluate accuracy
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# 0.4444444444444444
#
# Accuracy:44.44%
